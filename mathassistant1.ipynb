# %% [markdown]
# <a href="https://colab.research.google.com/github/zizobasry-cell/ischool-data-science/blob/main/mathassistant1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create custsom file
def mininumber( X , Y):
  if X < Y:
    print( X )
  else:
    print(Y)
def maximumnumber( X , Y):
  if X > Y:
    print(X)
  else:
    print(Y)
def addnumber (x , y ):
  print( x + y)
def Subtractionnumber (x , y ):
  print (x - y)
def multiplicationnumber ( x , y ) :
  print( x * y)
def divisionnumber ( x , y ) :
  print( x / y)
