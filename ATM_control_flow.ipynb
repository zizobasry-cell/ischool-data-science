# %% [markdown]
# <a href="https://colab.research.google.com/github/zizobasry-cell/ischool-data-science/blob/main/ATM_control_flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Password = 1109
Balance = 20000

while True:
  password_user = int(input("Enter your password: "))
  while Password != password_user:
        print("WRONG PASS !! Enter your correct password ")
        password_user = int(input("Enter your password: "))

  print("for checking balance press 1 , for cash withdrawal press 2 , for cash deposit press 3 ")
  option = int(input("choose an operation: "))
  if option == 1:
         print("Your balance is : ", Balance)
  elif option == 2:
        requested_ammount = int(input(" Enter the ammount you want to whidrawal : "))
        if requested_ammount <= Balance:
            Balance = Balance - requested_ammount
            print("transaction successful ")
        else:
            print("Insufficient balance")
  elif option == 3:
        cash_deposit = int(input("Enter the ammount you want to deposit : "))
        Balance = Balance + cash_deposit
        print("transaction successful")
        print("your total balance is : ", Balance)
  else:
     print("thank you")
     break
